# %% [markdown]
# Assignment: Create a Python project which will depict following charts
#
# Chart 1: Total month wise Covid-19 cases in the United States year to date
#
# Chart 2: Number of cases(state wise)
#
# Chart 3: Number of cases recovered(state wise)
#
# Chart 4: Top 5 countries based on number of cases

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('WhoData.csv')
df.head()
# Out:
#                        Name       WHO Region  Cases - cumulative total  \
# 0                    Global              NaN                 111102016
# 1  United States of America         Americas                  27773047
# 2                     India  South-East Asia                  11005850
# 3                    Brazil         Americas                  10139148
# 4        Russian Federation           Europe                   4177330
#
#    Cases - cumulative total per 100000 population  \
# 0                                     1423.233341
# 1                                     8390.580000
# 2                                      797.520000
# 3                                     4770.030000
# 4                                     2862.470000
#
#    Cases - newly reported in last 7 days  \
# 0                                2449756
# 1                                 463544
# 2                                  89261
# 3                                 329394
# ...

# %%
df = df.rename(columns={'Cases - cumulative total': 'total_cases',
                       'Name': 'country_names'})
df.head()
# Out:
#               country_names       WHO Region  total_cases  \
# 0                    Global              NaN    111102016
# 1  United States of America         Americas     27773047
# 2                     India  South-East Asia     11005850
# 3                    Brazil         Americas     10139148
# 4        Russian Federation           Europe      4177330
#
#    Cases - cumulative total per 100000 population  \
# 0                                     1423.233341
# 1                                     8390.580000
# 2                                      797.520000
# 3                                     4770.030000
# 4                                     2862.470000
#
#    Cases - newly reported in last 7 days  \
# 0                                2449756
# 1                                 463544
# 2                                  89261
# 3                                 329394
# 4                                  91240
#
# ...

# %%
df = df.loc[1:]
df.head()
# Out:
#               country_names       WHO Region  total_cases  \
# 1  United States of America         Americas     27773047
# 2                     India  South-East Asia     11005850
# 3                    Brazil         Americas     10139148
# 4        Russian Federation           Europe      4177330
# 5        The United Kingdom           Europe      4115513
#
#    Cases - cumulative total per 100000 population  \
# 1                                         8390.58
# 2                                          797.52
# 3                                         4770.03
# 4                                         2862.47
# 5                                         6062.39
#
#    Cases - newly reported in last 7 days  \
# 1                                 463544
# 2                                  89261
# 3                                 329394
# 4                                  91240
# 5                                  77431
#
# ...

# %%
cases = df.loc[:, 'total_cases'].values
countries = df.loc[:, 'country_names'].values
cases[:5]
# Out:
# array([27773047, 11005850, 10139148,  4177330,  4115513])

# %%
plt.figure(figsize=(20, 5))
plt.plot(countries[:5], cases[:5], marker = '.', markersize = 20)
plt.xlabel('Countries')
plt.ylabel('Cases')
# Out:
# Text(0, 0.5, 'Cases')

# %%
#help(plt.plot)

# %%
plt.style.use('seaborn-ticks')
plt.figure(figsize=(10, 5))
plt.bar(countries[:5], cases[:5])
plt.xticks(rotation=10)
#plt.xticks(size=15)
#sns.set(font_scale=1.4)
# Out:
# ([0, 1, 2, 3, 4], <a list of 5 Text xticklabel objects>)

# %%
help(plt.style)
# Out:
# Help on package matplotlib.style in matplotlib:
#
# NAME
#     matplotlib.style
#
# PACKAGE CONTENTS
#     core
#
# DATA
#     available = ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fiv...
#     library = {'Solarize_Light2': RcParams({'axes.axisbelow': True,
#           ...
#
# FILE
#     /Users/janki/opt/anaconda3/lib/python3.7/site-packages/matplotlib/style/__init__.py

# %%
# help(sns.barplot)

# %%
sns.set_palette("pastel")
plt.figure(figsize=(10,5))
# sns.barplot(countries[:5], cases[:5])
plt1 = sns.barplot(x=df['country_names'][:5], y=df['total_cases'], data = df)
plt1.set(xlabel='Countries', ylabel = 'Total Cases')
plt1.set_xticklabels(labels=df['country_names'], rotation=30, horizontalalignment='center')
#plt1.set_xticklabels(rotation=30)
# sns.set(font_scale=1.4)

# crashes = sns.load_dataset('car_crashes').sort_values('total', ascending = False)
# f, ax = plt.subplots(figsize = (6,15))
# sns.set_color_codes('pastel')
# sns.barplot(x = 'total', y = 'abbrev', data = crashes,
#             label = 'Total', color = 'b', edgecolor = 'w')
# sns.set_color_codes('muted')
# sns.barplot(x = 'alcohol', y = 'abbrev', data = crashes,
#             label = 'Alcohol-involved', color = 'b', edgecolor = 'w')
# ax.legend(ncol = 2, loc = 'lower right')
# sns.despine(left = True, bottom = True)
# plt.show()
# Out:
# [Text(0, 0, 'United States of America'),
#  Text(0, 0, 'India'),
#  Text(0, 0, 'Brazil'),
#  Text(0, 0, 'Russian Federation'),
#  Text(0, 0, 'The United Kingdom')]

# %% [raw]
# Chart 1: Total month wise Covid-19 cases in the United States year to date

# %%
us_df = pd.read_csv('USCovidCases.csv')
us_df.head()
# Out:
#   submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0         4/15/20    RI       3529         NaN         NaN       160
# 1         3/23/20    NH        101         NaN         NaN        23
# 2         8/21/20    MD     103523         NaN         NaN       624
# 3         2/27/21    MS     294795    182857.0    111938.0       704
# 4         3/12/20    NJ         29         NaN         NaN         6
#
#    pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 0        NaN         87         NaN         NaN          7         NaN
# 1        NaN          1         NaN         NaN          1         NaN
# 2        0.0       3685      3546.0       139.0         11         1.0
# 3      478.0       6681      4672.0      2009.0         12         7.0
# 4        NaN          1         NaN         NaN          0         NaN
#
#       created_at consent_cases consent_deaths
# 0  4/15/20 16:22     Not agree            NaN
# ...

# %%
us_df = monthly_us_df.sort_values(by=['submission_date'], ascending=False)
us_df.head()
#monthly_us_df.info()
# check = monthly_us_df[monthly_us_df['state'] == 'IL']
# check.sort_values(by=['state'], ascending=False)
# check
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 19029      12/31/2020    DE      58064     55670.0      2394.0      1468
# 10625      12/31/2020    PA     640325    574364.0     65961.0      8992
# 22060      12/31/2020    MT      81555     81555.0         0.0       255
# 9501       12/31/2020    FL    1300528         NaN         NaN     16827
# 19725      12/31/2020    WA     246752         NaN         NaN      4422
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 19029       90.0        930       828.0       102.0          9         0.0
# 10625     1909.0      15978         NaN         NaN        306       237.0
# 22060        0.0        961       961.0         0.0         11         0.0
# 9501         0.0      21673         NaN         NaN        127         0.0
# 19725      250.0       3461         NaN         NaN         41         0.0
#
#                    created_at consent_cases consent_deaths     Month  \
# ...

# %%
# month_sum = monthly_us_df.sum(axis=0)
# month_sum
# month_sum = monthly_us_df.groupby('submission_date').sum()
# month_sum.head()
#month_sum['submission_date'] = pd.to_datetime(month_sum['submission_date'])
#monthly_us_df.groupby(monthly_us_df['submission_date'].dt.strftime('%B'))['new_case'].sum().sort_values()
# month_sum
# In [6]: df['date'] = pd.to_datetime(df['date'])

df1 = pd.DataFrame({'date':['6/2/2017','5/23/2017','5/20/2017','6/22/2017','6/21/2017'],'Revenue':[100,200,300,400,500]})
df1.date = pd.to_datetime(df1.date)
dg = df1.groupby(pd.Grouper(key='date', freq='1M')).sum() # groupby each 1 month
dg.index = dg.index.strftime('%B')
dg
# df['Date'] = pd.to_datetime(df['Date'])
# >>> df.set_index('Date',inplace=True)
# >>> df['withdrawal'].resample('M').sum().sort_values()

# monthly_us_df.submission_date = pd.to_datetime(monthly_us_df.submission_date)
# tempdf = monthly_us_df.set_index(monthly_us_df['submission_date'], inplace=True)
# temp = monthly_us_df['new_case'].resample('M').sum().sort_values()
# temp.sort_values(by=['submission_date'], ascending=True)
# plt.figure(figsize=(50, 20))
# plt.plot(temp, marker='.', markersize='20')

# monthly_us_df = monthly_us_df.sort_values(by=['submission_date'], ascending=False)
# df = df.sort_values(by = 'Date')
# monthly_us_df.sort_values(by = monthly_us_df['submission_date'])
# monthly_us_df.groupby(by=monthly_us_df['submission_date'])
us_df['Month'] = pd.DatetimeIndex(us_df['submission_date']).month_name()
us_df.head()
#temp = monthly_us_df.groupby(by=monthly_us_df['submission_date'])['new_case'].sum().sort_values()
# df.groupby(df['date'].dt.strftime('%B'))['Revenue'].sum().sort_values()
us_df.head()

us_df['report_date']= pd.to_datetime(monthly_us_df['submission_date']) 
result = us_df.groupby([us_df['report_date'].dt.year, us_df['report_date'].dt.month]).agg({'new_case':sum})
plt.style.use('seaborn')
plt.figure(figsize=(8, 5))
plt.plot(result.loc[:, 'new_case'].values, marker='.', markersize='20')
# plt.bar(height=result['new_case'], x=result.index.to_pydatetime())
# plt.bar(result['new_case'], height=result['new_case'])
# help(plt.bar)
# monthly_us_df.submission_date = pd.to_datetime(monthly_us_df.submission_date)
# abcd = monthly_us_df.groupby(pd.Grouper(key='submission_date', freq='1M')).sum()
# abcd.index = abcd.index.strftime('%B')
# abcd
# In [7]: df
# Out[7]: 
#         date  Revenue
# 0 2017-06-02      100
# 1 2017-05-23      200
# 2 2017-05-20      300
# 3 2017-06-22      400
# 4 2017-06-21      500
# In [59]: df.groupby(df['date'].dt.strftime('%B'))['Revenue'].sum().sort_values()
# Out[59]: 
# date
# May      500
# June    1000

# month = month_sum.loc[:, 'submission_date'].values
# cases = month_sum.loc[:, 'tot_cases'].values
# cases
# plt.figure(figsize=(400, 200))
# plt.plot(month_sum.index.values, cases, marker='.', markersize='20')

# grouped_df = df.groupby("A")
# df["sum_column"] = grouped_df[["B"]].transform(sum)
# df = df.sort_values("sum_column", ascending=True)
# df = df.drop("sum_column", axis=1)

# %%
sns.set_palette("pastel")
plt.figure(figsize=(10,5))
plt1 = sns.barplot(x=result.index, y=result.new_case, data = result)
plt1.set(xlabel='Date', ylabel = 'Total Cases')
plt1.set_xticklabels(labels=result.index, rotation=30, horizontalalignment='center')
# result.info()
# Out:
# [Text(0, 0, '(2020, 1)'),
#  Text(0, 0, '(2020, 2)'),
#  Text(0, 0, '(2020, 3)'),
#  Text(0, 0, '(2020, 4)'),
#  Text(0, 0, '(2020, 5)'),
#  Text(0, 0, '(2020, 6)'),
#  Text(0, 0, '(2020, 7)'),
#  Text(0, 0, '(2020, 8)'),
#  Text(0, 0, '(2020, 9)'),
#  Text(0, 0, '(2020, 10)'),
#  Text(0, 0, '(2020, 11)'),
#  Text(0, 0, '(2020, 12)'),
#  Text(0, 0, '(2021, 1)'),
#  Text(0, 0, '(2021, 2)'),
#  Text(0, 0, '(2021, 3)')]

# %%
us_df[:-1]
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 19029      12/31/2020    DE      58064     55670.0      2394.0      1468
# 10625      12/31/2020    PA     640325    574364.0     65961.0      8992
# 22060      12/31/2020    MT      81555     81555.0         0.0       255
# 9501       12/31/2020    FL    1300528         NaN         NaN     16827
# 19725      12/31/2020    WA     246752         NaN         NaN      4422
# ...               ...   ...        ...         ...         ...       ...
# 9054       01/01/2021    WV      87820     71250.0     16570.0      2486
# 20249      01/01/2021    LA     315275         NaN         NaN         0
# 22577      01/01/2021    IL     963389    963389.0         0.0         0
# 9272       01/01/2021    TX    1772483         NaN         NaN     16311
# 15137      01/01/2021    AR     229442         NaN         NaN      4304
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
# Chart 2: Number of cases(state wise)

# us_df['report_date']= pd.to_datetime(monthly_us_df['submission_date']) 
# result = us_df.groupby([us_df['report_date'].dt.year, us_df['report_date'].dt.month]).agg({'new_case':sum})
plt.style.use('seaborn')
plt.figure(figsize=(20, 8))
# plt.plot(result.loc[:, 'new_case'].values, marker='.', markersize='20')
# us_df.head

us_df.groupby(by='state')
us_df.head()
# monthly_us_df.sort_values(by=['state'], ascending=True)
state_result = us_df.groupby(us_df['state']).agg({'new_case':sum})
plt.bar(height=state_result['new_case'], x=state_result.index)
plt.plot(state_result.loc[:, 'new_case'].values, marker='.', markersize='20', c='r')
# state_result

# %% [markdown]
# Chart 3: Number of cases recovered(state wise)

# %%
us_df.head()
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 19029      12/31/2020    DE      58064     55670.0      2394.0      1468
# 10625      12/31/2020    PA     640325    574364.0     65961.0      8992
# 22060      12/31/2020    MT      81555     81555.0         0.0       255
# 9501       12/31/2020    FL    1300528         NaN         NaN     16827
# 19725      12/31/2020    WA     246752         NaN         NaN      4422
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 19029       90.0        930       828.0       102.0          9         0.0
# 10625     1909.0      15978         NaN         NaN        306       237.0
# 22060        0.0        961       961.0         0.0         11         0.0
# 9501         0.0      21673         NaN         NaN        127         0.0
# 19725      250.0       3461         NaN         NaN         41         0.0
#
#                    created_at consent_cases consent_deaths     Month  \
# ...

# %%
us_cases_recovered = pd.read_csv('us_state_data.csv')
us_cases_recovered = us_cases_recovered.rename(columns={'USA': 'state', 'Total.1' : 'total_death', 
                    'New.1': 'new_death', 'Total.2': 'total_recovered', 'Total.3':'total_tests', 'Tests': 'test_1M_pop'})
# help(us_cases_recovered.drop())
us_cases_recovered = us_cases_recovered.loc[2:]
# us_cases_recovered = us_cases_recovered.sort_values(by=['state'])

# us_cases_recovered = us_cases_recovered.sort_values(us_cases_recovered['US_states'], ascending=True)
# crashes = sns.load_dataset('car_crashes').sort_values('total', ascending = False)

us_cases_recovered
# Out:
#                    state      Total    New total_death new_death  \
# 2             California  3,657,053    NaN      58,283       NaN
# 3                  Texas  2,778,572    NaN      48,186       NaN
# 4                Florida  2,033,179    NaN      33,133       NaN
# 5               New York  1,874,285    NaN      50,157       NaN
# 6               Illinois  1,232,900    NaN      23,472       NaN
# 7                Georgia  1,053,020    NaN      18,849       NaN
# 8           Pennsylvania  1,010,534    NaN      25,068       NaN
# 9                   Ohio  1,008,913    NaN      18,526       NaN
# 10        North Carolina    905,528    NaN      12,028       NaN
# 11            New Jersey    887,481    NaN      24,358       NaN
# 12               Arizona    838,558    NaN      16,898       NaN
# 13             Tennessee    806,792    NaN      11,816       NaN
# 14              Michigan    718,455    NaN      17,023       NaN
# ...

# %%
nan_recovered = us_cases_recovered['total_recovered'].isnull() == True
# us_cases_recovered.loc[nan_recovered, :] = us_cases_recovered['Total'].sub(us_cases_recovered['total_death'])
# df.Temp_Rating.fillna(df.Farheit, inplace=True)
us_cases_recovered['Total'] = us_cases_recovered['Total'].str.replace(',', '')
us_cases_recovered['total_death'] = us_cases_recovered['total_death'].str.replace(',', '')
us_cases_recovered['total_recovered'] = us_cases_recovered.total_recovered.fillna(us_cases_recovered['Total'].astype(int) - us_cases_recovered['total_death'].astype(int))
# .map('{:,.2f}'.format))

# plt.bar(height=state_result['new_case'], x=state_result.index)

plt.figure(figsize=(30, 30))
# # plt.bar(height = us_cases_recovered['total_recovered'], x = us_cases_recovered['state'])
if(us_cases_recovered['total_recovered'].dtype != np.number):
    us_cases_recovered['total_recovered'] = us_cases_recovered['total_recovered'].str.replace(',', '')
    us_cases_recovered["total_recovered"] = pd.to_numeric(us_cases_recovered.loc[:, "total_recovered"])

# y_pos = np.arange(len(us_cases_recovered.state))
plt.barh(y=us_cases_recovered.state, width=us_cases_recovered.total_recovered)
# plt.yticks(y_pos, us_cases_recovered.state)

# plt.plot(us_cases_recovered['total_recovered'].index, marker='.', markersize='20', c='r')
# plt.plot(state_result.loc[:, 'new_case'].values, marker='.', markersize='20', c='r')
# plt.bar(height=state_result['new_case'], x=state_result.index)
# plt.xlabel(us_cases_recovered.state)
# plt.xticks(rotation=10)
# us_cases_recovered['total_recovered']
# Out:
# <BarContainer object of 51 artists>

# %%
us_cases_recovered
# Out:
#                    state    Total    New total_death new_death  \
# 2             California  3657053    NaN       58283       NaN
# 3                  Texas  2778572    NaN       48186       NaN
# 4                Florida  2033179    NaN       33133       NaN
# 5               New York  1874285    NaN       50157       NaN
# 6               Illinois  1232900    NaN       23472       NaN
# 7                Georgia  1053020    NaN       18849       NaN
# 8           Pennsylvania  1010534    NaN       25068       NaN
# 9                   Ohio  1008913    NaN       18526       NaN
# 10        North Carolina   905528    NaN       12028       NaN
# 11            New Jersey   887481    NaN       24358       NaN
# 12               Arizona   838558    NaN       16898       NaN
# 13             Tennessee   806792    NaN       11816       NaN
# 14              Michigan   718455    NaN       17023       NaN
# 15               Indiana   682099    NaN       13002       NaN
# ...
